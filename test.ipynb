# %%
import pandas

# %%
df = pd.read_pickle('merged.pkl')

# %%
df
# Out:
#                  Gmt time  Open_AUDUSD  High_AUDUSD  Low_AUDUSD  Close_AUDUSD  \
# 0     2004-04-01 22:00:00      0.75793      0.75915     0.75719       0.75864
# 1     2004-04-01 23:00:00      0.75887      0.76064     0.75849       0.75911
# 2     2004-05-01 00:00:00      0.75914      0.76085     0.75907       0.76002
# 3     2004-05-01 01:00:00      0.76003      0.76160     0.75970       0.76129
# 4     2004-05-01 02:00:00      0.76103      0.76175     0.76000       0.76105
# 5     2004-05-01 03:00:00      0.76104      0.76333     0.76063       0.76315
# 6     2004-05-01 04:00:00      0.76253      0.76335     0.76170       0.76278
# 7     2004-05-01 05:00:00      0.76277      0.76388     0.76225       0.76350
# 8     2004-05-01 06:00:00      0.76373      0.76455     0.76278       0.76422
# 9     2004-05-01 07:00:00      0.76415      0.76675     0.76364       0.76588
# 10    2004-05-01 08:00:00      0.76613      0.76643     0.76427       0.76521
# ...

# %%
close = df['Close_ZURUSD'].iloc[1:].reset_index(drop=True)

# %%
df['next_close_ZURUSD'] = close

# %%
df = df.iloc[:,1:]

# %%
df.values
# Out:
# array([[7.57930000e-01, 7.59150000e-01, 7.57190000e-01, ...,
#         1.26062000e+00, 2.86351992e+04, 1.26308000e+00],
#        [7.58870000e-01, 7.60640000e-01, 7.58490000e-01, ...,
#         1.26308000e+00, 3.32603984e+04, 1.26538000e+00],
#        [7.59140000e-01, 7.60850000e-01, 7.59070000e-01, ...,
#         1.26538000e+00, 3.29106016e+04, 1.26559000e+00],
#        ...,
#        [7.39340000e-01, 7.39660000e-01, 7.39010000e-01, ...,
#         1.16683000e+00, 1.03708799e+04, 1.16772000e+00],
#        [7.39600000e-01, 7.40200000e-01, 7.39160000e-01, ...,
#         1.16772000e+00, 1.12340098e+04, 1.16847000e+00],
#        [7.40090000e-01, 7.40890000e-01, 7.39970000e-01, ...,
#         1.16847000e+00, 5.78812010e+03,            nan]])
